# %%
import pandas as pd
import numpy as np
df=pd.read_csv('train_news.csv')
df
# Out:
#        Unnamed: 0     id                                           headline  \
# 0               0   9653  Ethics Questions Dogged Agriculture Nominee as...
# 1               1  10041  U.S. Must Dig Deep to Stop Argentina’s Lionel ...
# 2               2  19113  Cotton to House: ’Do Not Walk the Plank and Vo...
# 3               3   6868  Paul LePage, Besieged Maine Governor, Sends Co...
# 4               4   7596                       A Digital 9/11 If Trump Wins
# ...           ...    ...                                                ...
# 20795       20795   5671                                                NaN
# 20796       20796  14831        Albert Pike and the European Migrant Crisis
# 20797       20797  18142  Dakota Access Caught Infiltrating Protests to ...
# 20798       20798  12139  How to Stretch the Summer Solstice - The New Y...
# 20799       20799  15660  Emory University to Pay for ’100 Percent’ of U...
#
#                        written_by  \
# 0      Eric Lipton and Steve Eder
# 1                 David Waldstein
# 2                         Pam Key
# 3                    Jess Bidgood
# 4               Finian Cunningham
# ...                           ...
# 20795              NeverSurrender
# 20796               Rixon Stewart
# 20797                 Eddy Lavine
# 20798              Alison S. Cohn
# 20799                Tom Ciccotta
#
#                                                     news  label
# 0      WASHINGTON  —   In Sonny Perdue’s telling, Geo...      0
# 1      HOUSTON  —   Venezuela had a plan. It was a ta...      0
# 2      Sunday on ABC’s “This Week,” while discussing ...      0
# 3      AUGUSTA, Me.  —   The beleaguered Republican g...      0
# 4        Finian Cunningham has written extensively on...      1
# ...                                                  ...    ...
# 20795  No, you'll be a dog licking of the vomit of yo...      1
# 20796  By Rixon Stewart on November 5, 2016 Rixon Ste...      1
# 20797  posted by Eddie You know the Dakota Access Pip...      1
# 20798  It’s officially summer, and the Society Boutiq...      0
# 20799  Emory University in Atlanta, Georgia, has anno...      0
#
# [20800 rows x 6 columns]

# %%
df.drop(['Unnamed: 0','id','headline','written_by'],axis=1)
# Out:
#                                                     news  label
# 0      WASHINGTON  —   In Sonny Perdue’s telling, Geo...      0
# 1      HOUSTON  —   Venezuela had a plan. It was a ta...      0
# 2      Sunday on ABC’s “This Week,” while discussing ...      0
# 3      AUGUSTA, Me.  —   The beleaguered Republican g...      0
# 4        Finian Cunningham has written extensively on...      1
# ...                                                  ...    ...
# 20795  No, you'll be a dog licking of the vomit of yo...      1
# 20796  By Rixon Stewart on November 5, 2016 Rixon Ste...      1
# 20797  posted by Eddie You know the Dakota Access Pip...      1
# 20798  It’s officially summer, and the Society Boutiq...      0
# 20799  Emory University in Atlanta, Georgia, has anno...      0
#
# [20800 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
import pandas as pd
df['news'] = df['news'].fillna('')
x = df['news']
y = df['label']
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.2, random_state=50)
vectorize=CountVectorizer()
x_train_vect = vectorize.fit_transform(train_x)
x_test_vect = vectorize.transform(test_x)
merged_x_vect = vectorize.transform(pd.concat([train_x, test_x], axis=0, ignore_index=True))
k = 3
kmeans_cluster = KMeans(n_clusters=k, random_state=50)
kmeans_cluster.fit(merged_x_vect)
df['clusters'] = kmeans_cluster.predict(merged_x_vect)
print(df)
# Out:
# C:\Users\madhu\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#        Unnamed: 0     id                                           headline  \
# 0               0   9653  Ethics Questions Dogged Agriculture Nominee as...
# 1               1  10041  U.S. Must Dig Deep to Stop Argentina’s Lionel ...
# 2               2  19113  Cotton to House: ’Do Not Walk the Plank and Vo...
# 3               3   6868  Paul LePage, Besieged Maine Governor, Sends Co...
# 4               4   7596                       A Digital 9/11 If Trump Wins
# ...           ...    ...                                                ...
# 20795       20795   5671                                                NaN
# 20796       20796  14831        Albert Pike and the European Migrant Crisis
# 20797       20797  18142  Dakota Access Caught Infiltrating Protests to ...
# 20798       20798  12139  How to Stretch the Summer Solstice - The New Y...
# 20799       20799  15660  Emory University to Pay for ’100 Percent’ of U...
#
#                        written_by  \
# 0      Eric Lipton and Steve Eder
# 1                 David Waldstein
# 2                         Pam Key
# 3                    Jess Bidgood
# 4               Finian Cunningham
# ...                           ...
# 20795              NeverSurrender
# 20796               Rixon Stewart
# 20797                 Eddy Lavine
# 20798              Alison S. Cohn
# 20799                Tom Ciccotta
#
#                                                     news  label  clusters
# 0      WASHINGTON  —   In Sonny Perdue’s telling, Geo...      0         0
# 1      HOUSTON  —   Venezuela had a plan. It was a ta...      0         0
# 2      Sunday on ABC’s “This Week,” while discussing ...      0         0
# 3      AUGUSTA, Me.  —   The beleaguered Republican g...      0         0
# 4        Finian Cunningham has written extensively on...      1         0
# ...                                                  ...    ...       ...
# 20795  No, you'll be a dog licking of the vomit of yo...      1         0
# 20796  By Rixon Stewart on November 5, 2016 Rixon Ste...      1         0
# 20797  posted by Eddie You know the Dakota Access Pip...      1         0
# 20798  It’s officially summer, and the Society Boutiq...      0         1
# 20799  Emory University in Atlanta, Georgia, has anno...      0         0
#
# [20800 rows x 7 columns]

# %% [raw]
# df.isnull().sum()

# %%
df_without_labels
# Out:
#        Unnamed: 0     id                                           headline  \
# 0               0   9653  Ethics Questions Dogged Agriculture Nominee as...
# 1               1  10041  U.S. Must Dig Deep to Stop Argentina’s Lionel ...
# 2               2  19113  Cotton to House: ’Do Not Walk the Plank and Vo...
# 3               3   6868  Paul LePage, Besieged Maine Governor, Sends Co...
# 4               4   7596                       A Digital 9/11 If Trump Wins
# ...           ...    ...                                                ...
# 20795       20795   5671                                                NaN
# 20796       20796  14831        Albert Pike and the European Migrant Crisis
# 20797       20797  18142  Dakota Access Caught Infiltrating Protests to ...
# 20798       20798  12139  How to Stretch the Summer Solstice - The New Y...
# 20799       20799  15660  Emory University to Pay for ’100 Percent’ of U...
#
#                        written_by  \
# 0      Eric Lipton and Steve Eder
# 1                 David Waldstein
# 2                         Pam Key
# 3                    Jess Bidgood
# 4               Finian Cunningham
# ...                           ...
# 20795              NeverSurrender
# 20796               Rixon Stewart
# 20797                 Eddy Lavine
# 20798              Alison S. Cohn
# 20799                Tom Ciccotta
#
#                                                     news  clusters
# 0      WASHINGTON  —   In Sonny Perdue’s telling, Geo...         0
# 1      HOUSTON  —   Venezuela had a plan. It was a ta...         0
# 2      Sunday on ABC’s “This Week,” while discussing ...         0
# 3      AUGUSTA, Me.  —   The beleaguered Republican g...         0
# 4        Finian Cunningham has written extensively on...         0
# ...                                                  ...       ...
# 20795  No, you'll be a dog licking of the vomit of yo...         0
# 20796  By Rixon Stewart on November 5, 2016 Rixon Ste...         0
# 20797  posted by Eddie You know the Dakota Access Pip...         0
# 20798  It’s officially summer, and the Society Boutiq...         2
# 20799  Emory University in Atlanta, Georgia, has anno...         0
#
# [20800 rows x 6 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt 
avg_dist=[]
k_values=range(1,32)
for k in k_values:
    kmeans=KMeans(n_clusters=k,random_state=50)
    kmeans.fit(merged_x_vect.toarray())
    avg_distance=kmeans.inertia_/len(merged_x_vect)
    avg_dist.append(avg_distance)
plt.figure(figsize=(10, 6))
plt.plot(k_values, avg_dist, marker='o', linestyle='-', color='b')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Average Euclidean Distance')
plt.xticks(k_values)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 7
#       5 for k in k_values:
#       6     kmeans=KMeans(n_clusters=k,random_state=50)
# ----> 7     kmeans.fit(merged_x_vect.toarray())
#       8     avg_distance=kmeans.inertia_/len(merged_x_vect)
#       9     avg_dist.append(avg_distance)
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_compressed.py:1051, in _cs_matrix.toarray(self, order, out)
#    1049 if out is None and order is None:
#    1050     order = self._swap('cf')[0]
# -> 1051 out = self._process_toarray_args(order, out)
#    1052 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1053     raise ValueError('Output array must be C or F contiguous')
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_base.py:1298, in spmatrix._process_toarray_args(self, order, out)
#    1296     return out
#    1297 else:
# -> 1298     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 28.0 GiB for an array with shape (20800, 180445) and data type int64
